# %%
import numpy as np
import pandas as pd

# %%
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go

# %%
data = pd.read_csv('/Users/apple/NBA-player-data-dash-plotly/2012-18_playerBoxScore.csv',
                            parse_dates=['gmDate'])

# %%
data.dtypes
# Out:
# gmDate        datetime64[ns]
# gmTime                object
# seasTyp               object
# playLNm               object
# playFNm               object
# teamAbbr              object
# teamConf              object
# teamDiv               object
# teamLoc               object
# teamRslt              object
# teamDayOff             int64
# offLNm1               object
# offFNm1               object
# offLNm2               object
# offFNm2               object
# offLNm3               object
# offFNm3               object
# playDispNm            object
# playStat              object
# playMin                int64
# playPos               object
# playHeight             int64
# playWeight             int64
# playBDate             object
# playPTS                int64
# playAST                int64
# playTO                 int64
# playSTL                int64
# playBLK                int64
# playPF                 int64
# playFGA                int64
# playFGM                int64
# ...

# %% [markdown]
# ### columns
# gmDate
#
# teamRslt
#
# playDispNm
#
# playMin
#
# playPTS
#
# playAST
#
# playTO
#
# playSTL
#
# playBLK
#
# playPF

# %%
data_player = data.loc[:, ['gmDate', 'teamRslt', 'playDispNm', 'playMin', 'playPTS', 'playAST', 'playTO', 'playSTL', 'playBLK', 'playPF']]
data_player.head()
# Out:
#       gmDate teamRslt     playDispNm  playMin  playPTS  playAST  playTO  \
# 0 2012-10-30     Loss     A.J. Price       29        7        6       1
# 1 2012-10-30     Loss   Trevor Ariza       25        9        4       0
# 2 2012-10-30     Loss   Emeka Okafor       25       10        0       1
# 3 2012-10-30     Loss   Bradley Beal       22        8        3       2
# 4 2012-10-30     Loss  Trevor Booker       17        4        1       4
#
#    playSTL  playBLK  playPF
# 0        0        0       1
# 1        3        2       0
# 2        0        4       1
# 3        1        0       1
# 4        1        1       4

# %%
data_price = data[(data['playDispNm'].isin(['A.J. Price']))]

# %%
go.Scatter(go.Scatter(
            x= data_price.gmDate,
            y= data_price.playPTS,
            mode='lines'))
# Out:
# Scatter({
#     'mode': 'lines',
#     'x': array(['2012-10-30', '2012-11-03', '2012-11-07', '2012-11-09', '2012-11-10',
#                 '2012-11-13', '2012-11-14', '2012-11-17', '2012-11-19', '2012-11-21',
#                 '2012-11-24', '2012-11-26', '2012-11-28', '2012-11-30', '2012-12-04',
#                 '2012-12-07', '2012-12-08', '2013-01-07', '2013-01-12', '2013-01-14',
#                 '2013-01-16', '2013-01-18', '2013-01-19', '2013-01-21', '2013-01-23',
#                 '2013-01-25', '2013-01-26', '2013-01-28', '2013-01-30', '2013-02-01',
#                 '2013-02-02', '2013-02-04', '2013-02-06', '2013-02-08', '2013-02-11',
#                 '2013-02-13', '2013-02-19', '2013-02-22', '2013-02-23', '2013-02-25',
#                 '2013-02-27', '2013-03-03', '2013-03-06', '2013-03-08', '2013-03-09',
#                 '2013-03-12', '2013-03-29', '2013-03-31', '2013-04-02', '2013-04-03',
# ...

# %%
dictlist = []
unique_list = data.playDispNm.unique()
unique_list.sort()
for title in unique_list:
    dictlist.append({'value': title, 'label': title})

# %%
list(dictlist[0].values())
# Out:
# ['A.J. Hammons', 'A.J. Hammons']

# %%
data_player.gmDate.min
# Out:
# <bound method Series.min of 0        2012-10-30
# 1        2012-10-30
# 2        2012-10-30
# 3        2012-10-30
# 4        2012-10-30
# 5        2012-10-30
# 6        2012-10-30
# 7        2012-10-30
# 8        2012-10-30
# 9        2012-10-30
# 10       2012-10-30
# 11       2012-10-30
# 12       2012-10-30
# 13       2012-10-30
# 14       2012-10-30
# 15       2012-10-30
# 16       2012-10-30
# 17       2012-10-30
# 18       2012-10-30
# 19       2012-10-30
# 20       2012-10-30
# 21       2012-10-30
# 22       2012-10-30
# 23       2012-10-30
# 24       2012-10-30
# 25       2012-10-30
# 26       2012-10-30
# 27       2012-10-30
# 28       2012-10-30
# 29       2012-10-30
#             ...
# 155683   2018-04-11
# 155684   2018-04-11
# 155685   2018-04-11
# 155686   2018-04-11
# 155687   2018-04-11
# 155688   2018-04-11
# 155689   2018-04-11
# 155690   2018-04-11
# 155691   2018-04-11
# 155692   2018-04-11
# 155693   2018-04-11
# 155694   2018-04-11
# 155695   2018-04-11
# ...

# %%
data.tail(1).values
# Out:
# array([[Timestamp('2018-04-11 00:00:00'), '10:30', 'Regular', 'Cooley',
#         'Jack', 'SAC', 'West', 'Pacific', 'Home', 'Win', 2, 'Tiven',
#         'Josh', 'Orr', 'J.T.', 'Foster', 'Scott', 'Jack Cooley', 'Bench',
#         18, 'PF', 81, 246, '1991-04-04', 10, 1, 2, 0, 0, 3, 4, 1, 0.25,
#         4, 1, 0.25, 0, 0, 0.0, 10, 8, 0.8, 1, 3, 4, 'HOU', 'West',
#         'Southwest', 'Away', 'Loss', 1]], dtype=object)

# %%
data[(data['playDispNm']=='Jack Cooley') & (data['gmDate'].dt.year==2015)]
# Out:
#           gmDate gmTime  seasTyp playLNm playFNm teamAbbr teamConf    teamDiv  \
# 69717 2015-02-27  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 72477 2015-03-16  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 72853 2015-03-18  22:30  Regular  Cooley    Jack      UTA     West  Northwest
# 72921 2015-03-19  22:30  Regular  Cooley    Jack      UTA     West  Northwest
# 73282 2015-03-21  22:30  Regular  Cooley    Jack      UTA     West  Northwest
# 73995 2015-03-25  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 74305 2015-03-27  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 74422 2015-03-28  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 74734 2015-03-30  20:00  Regular  Cooley    Jack      UTA     West  Northwest
# 75067 2015-04-01  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# 75707 2015-04-05  21:00  Regular  Cooley    Jack      UTA     West  Northwest
# ...

# %%
data[data['playDispNm']=='Jack Cooley']
# Out:
#            gmDate gmTime  seasTyp playLNm playFNm teamAbbr teamConf  \
# 69717  2015-02-27  21:00  Regular  Cooley    Jack      UTA     West
# 72477  2015-03-16  21:00  Regular  Cooley    Jack      UTA     West
# 72853  2015-03-18  22:30  Regular  Cooley    Jack      UTA     West
# 72921  2015-03-19  22:30  Regular  Cooley    Jack      UTA     West
# 73282  2015-03-21  22:30  Regular  Cooley    Jack      UTA     West
# 73995  2015-03-25  21:00  Regular  Cooley    Jack      UTA     West
# 74305  2015-03-27  21:00  Regular  Cooley    Jack      UTA     West
# 74422  2015-03-28  21:00  Regular  Cooley    Jack      UTA     West
# 74734  2015-03-30  20:00  Regular  Cooley    Jack      UTA     West
# 75067  2015-04-01  21:00  Regular  Cooley    Jack      UTA     West
# 75707  2015-04-05  21:00  Regular  Cooley    Jack      UTA     West
# 76126  2015-04-08  21:00  Regular  Cooley    Jack      UTA     West
# 76450  2015-04-10  21:00  Regular  Cooley    Jack      UTA     West
# ...

# %%
data[['gmDate']].set_index('gmDate').resample('A-OCT')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-ea4aac82ab5d> in <module>
# ----> 1 data['gmDate'] in (data[['gmDate']].set_index('gmDate').resample('A-OCT'))
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1714
#    1715             res_values = dispatch_to_index_op(op, self, other,
# -> 1716                                               pd.DatetimeIndex)
#    1717
#    1718             return self._constructor(res_values, index=self.index,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ...

# %%
data[['gmDate']].apply(lambda x: x in pd.date_range('2014-04-02',periods=10,freq='D',normalize=True))
# Out:
# gmDate    False
# dtype: bool

# %%
start_date='2018-03-02'
data[['gmDate']] > start_date
# Out:
#         gmDate
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# ...        ...
# 155683    True
# 155684    True
# 155685    True
# 155686    True
# 155687    True
# 155688    True
# 155689    True
# 155690    True
# 155691    True
# 155692    True
# 155693    True
# 155694    True
# 155695    True
# 155696    True
# 155697    True
# 155698    True
# 155699    True
# 155700    True
# 155701    True
# 155702    True
# 155703    True
# 155704    True
# 155705    True
# 155706    True
# 155707    True
# 155708    True
# ...
